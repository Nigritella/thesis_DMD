# %% [markdown]
# # Exploring fixed points in the homogeneous scenario
# Computation of the fixed points of our model under conditions of spatial homogeneity (i.e., with no diffusion term). Since we are interested in the stationary state, we can assume that time goes to infinity. Under this assumption, the damage function no longer contributes to the evolution, resulting in a simplified version of the model.

# %%
import numpy as np
import configparser
import math
from scipy.optimize import root
from scipy.linalg import eig
from pyDOE import lhs
import random
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# %% [markdown]
# ### Extract values from the configuration file

# %%
def extract_values(section_name, config):
    values = []
    if section_name in config:
        for key, value in config[section_name].items():
            values.append(float(value))
    else:
        print(f'Section "{section_name}" is not in the configuration file')
    return values

# %% [markdown]
# ### Set random initial guesses for the fixed points
#
# The ranges are chosen based on the maximum and minimum values that the state variables assume in the simulations from the reference paper. Mass must always be conserved, which means that our guesses should satisfy the condition: N+D+R=100

# %%
def set_initial_guess(num_samples):

    ranges = {
        'H': (0, 4500),
        'C': (0, 450),
        'M': (0, 100000),
        'N': (0, 100),
        'D': (0, 100)
    }

#symbol * is used to unpack the tuples, which are the values from the dictionary "ranges"
    random_values = {
        'H': [random.randint(*ranges['H']) for _ in range(num_samples)],
        'C': [random.randint(*ranges['C']) for _ in range(num_samples)],
        'M': [random.randint(*ranges['M']) for _ in range(num_samples)]
    }

    random_values['N'] = [random.randint(*ranges['N']) for _ in range(num_samples)]
#Generate D such that N + D <= 100
    random_values['D'] = [random.randint(0, min(100 - random_values['N'][i], ranges['D'][1])) for i in range(num_samples)]
#R = 100 - N - D
    random_values['R'] = [100 - random_values['D'][i] - random_values['N'][i] for i in range(num_samples)]

#Combine all variables into the initial_guess list of lists
    initial_guess = [
        [random_values['H'][i], random_values['C'][i], random_values['M'][i], random_values['N'][i], random_values['D'][i], random_values['R'][i]]
        for i in range(num_samples)
    ]

    return initial_guess

# %% [markdown]
# ### Define the system of algebraic equations
#
# In the homogeneous case, to study the fixed points, the system of ODEs is transformed into a system of algebraic equations. We aim to find the roots of these equations based on an initial guess. We ensure the conservation of mass by substituting the evolution equation for R with eq_R = 100 - R - N - D.

# %%
def equations(vars, par, H_i, C_i, M_i):
    
    H, C, M, N, D, R = vars
    k1, k2, k3, k4, k5, k6, d_H, d_C, d_M, d_D, sigma, m, h = par
    
    eq_H = d_H * H_i + k1 * D * M - d_H * H
    eq_C = d_C * C_i + k2 * D * H - d_C * C
    eq_M = d_M * M_i + k3 * D * M - d_M * M
    eq_N = k4 * R - k5 * C * N    
    eq_D = k5 * C * N - k6 * D * M - d_D * D
#The sixth equation would actually be: eq_R = k6 * D * M + d_D * D - k4 * R
    eq_R = 100 - R - N - D
    
    return [eq_H, eq_C, eq_M, eq_N, eq_D, eq_R]

# %% [markdown]
# ### Jacobian matrix

# %%
def jacobian(vars, par, H_i, C_i, M_i):

    H, C, M, N, D, R = vars
    k1, k2, k3, k4, k5, k6, d_H, d_C, d_M, d_D, sigma, m, h = par

#Initialize the Jacobian matrix (6x6 for 6 variables H, C, M, N, D, R)
    J = np.zeros((6, 6))
    
#Partial derivatives of eq_H = d_H * H_i + k1 * D * M - d_H * H
    J[0, 0] = - d_H
    J[0, 2] = k1 * D
    J[0, 4] = k1 * M
    
#Partial derivatives of eq_C = d_C * C_i + k2 * D * H - d_C * C
    J[1, 0] = k2 * D
    J[1, 1] = - d_C
    J[1, 4] = k2 * H
    
#Partial derivatives of eq_M = d_M * M_i + k3 * D * M - d_M * M
    J[2, 2] = k3 * D - d_M
    J[2, 4] = k3 * M
    
#Partial derivatives of eq_N = k4 * R - k5 * C * N 
    J[3, 1] = - k5 * N
    J[3, 3] = - k5 * C
    J[3, 5] = k4
    
#Partial derivatives of eq_D = k5 * C * N - k6 * D * M - d_D * D
    J[4, 1] = k5 * N
    J[4, 2] = - k6 * D
    J[4, 3] = k5 * C
    J[4, 4] = - k6 * M - d_D
    
#Partial derivatives of eq_R = 100 - R - D - N
    J[5, 3] = - 1
    J[5, 4] = - 1
    J[5, 5] = - 1

    return J

# %% [markdown]
# ### Fixed Points Analysis

# %%
num_samples = 250

#Extract values from the configuration file
config = configparser.ConfigParser()
config.read('config_fp.ini')

i_c = extract_values('initial_conditions', config)
par = extract_values('parameters', config)
H_i, C_i, M_i = i_c

#Random sampling
initial_guesses = set_initial_guess(num_samples) 

for i in range(num_samples):
    initial_guess = initial_guesses[i]
#Solve the system using the root function of the module optimize in scipy with Jacobian
    solution = root(equations, initial_guess, args=(par, H_i, C_i, M_i), jac=jacobian, method='lm')
    if not solution.success:
        print(f'Solution did not converge: {solution.message}')
    else:
        H, C, M, N, D, R = solution.x
        print(f'Initial guess {initial_guess}\nFixed Points:\nH = {H}, C = {C}, M = {M}, N = {N}, D = {D}, R = {R}\n')

#Compute the Jacobian matrix at the fixed point and its eigenvalues
        J = jacobian([H, C, M, N, D, R], par, H_i, C_i, M_i)
        eigenvalues = eig(J)[0]
        print(f'Eigenvalues of the Jacobian: {eigenvalues}\n')

        if all(np.real(eigenvalues) < 0):
            print(f'The fixed point is stable.\n\n\n')
        else:
            print(f'The fixed point is unstable.\n\n\n')
# Out:
# Initial guess [1963, 385, 45551, 77, 9, 14]
# Fixed Points:
# H = 30.24221113543999, C = 5.367830469485105, M = 1163.5357482046827, N = 83.62209206637402, D = 0.6687009105212885, R = 15.69634777199463
#
# Eigenvalues of the Jacobian: [-2.48497452e+00+0.j -1.27529486e+00+0.j -8.54264380e-01+0.j
#  -7.49546782e-01+0.j -7.98522887e-06+0.j -9.77666328e-02+0.j]
#
# The fixed point is stable.
#
#
#
# Initial guess [3255, 126, 64820, 9, 55, 36]
# Fixed Points:
# H = -16.329263840147036, C = -36.53768770833306, M = -12.08326264662368, N = -311.54886888273137, D = 34.752236453829504, R = 376.7966324289019
#
# Eigenvalues of the Jacobian: [25.8656119 +0.j         -2.97720617+0.j          0.38851854+0.j
#  -0.38642647+0.j         -0.8365514 +0.00640688j -0.8365514 -0.00640688j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [2285, 140, 75419, 22, 69, 9]
# Fixed Points:
# H = 840.6724761609644, C = 64.06289645193246, M = 21615.10560334646, N = 31.725232954143866, D = 1.000160813850851, R = 67.27460623200528
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [1446, 155, 94329, 68, 12, 20]
# Fixed Points:
# H = -51.44944167555137, C = -1.0755660574802406, M = -901.6824460298864, N = 101.53852406128783, D = 1.471052615490704, R = -3.018722500466498
#
# Eigenvalues of the Jacobian: [-1.12905999e+00+1.24957603j -1.12905999e+00-1.24957603j
#  -9.11512403e-01+0.j         -8.54886255e-01+0.j
#   1.61764169e-05+0.j         -1.28608755e-01+0.j        ]
#
# The fixed point is unstable.
#
#
#
# Initial guess [1554, 138, 4682, 92, 3, 5]
# Fixed Points:
# H = -51.45083337805604, C = -1.0756451112009666, M = -901.7176498116719, N = 101.53886420702034, D = 1.4710349677641925, R = -3.0190443235276874
#
# Eigenvalues of the Jacobian: [-1.12904648e+00+1.24959773j -1.12904648e+00-1.24959773j
#  -9.11514990e-01+0.j         -8.54886250e-01+0.j
#  -1.42496427e-05+0.j         -1.28604598e-01+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [1214, 387, 65081, 4, 31, 65]
# Fixed Points:
# H = 840.6724761609642, C = 64.06289645193243, M = 21615.10560334646, N = 31.725232954143873, D = 1.000160813850851, R = 67.27460623200527
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [2065, 201, 58091, 53, 36, 11]
# Fixed Points:
# H = 840.6724761609644, C = 64.06289645193246, M = 21615.105603346467, N = 31.725232954143863, D = 1.000160813850851, R = 67.27460623200528
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [960, 407, 35147, 15, 48, 37]
# Fixed Points:
# H = 840.6724761609642, C = 64.06289645193246, M = 21615.105603346456, N = 31.725232954143863, D = 1.0001608138508513, R = 67.27460623200528
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [1326, 10, 95262, 53, 28, 19]
# Fixed Points:
# H = -16.329263840147032, C = -36.53768770833306, M = -12.083262646623677, N = -311.5488688827315, D = 34.75223645382952, R = 376.796632428902
#
# Eigenvalues of the Jacobian: [25.8656119 +0.j         -2.97720617+0.j          0.38851854+0.j
#  -0.38642647+0.j         -0.8365514 +0.00640688j -0.8365514 -0.00640688j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [3643, 404, 99877, 41, 26, 33]
# Fixed Points:
# H = 30.241993300572794, C = 5.367813097228079, M = 1163.5302168515223, N = 83.62222386729279, D = 0.6686992671925828, R = 15.696219208494986
#
# Eigenvalues of the Jacobian: [-2.48497077e+00+0.j -1.27529573e+00+0.j -8.54264380e-01+0.j
#  -7.49547041e-01+0.j -1.08707977e-05+0.j -9.77657636e-02+0.j]
#
# The fixed point is stable.
#
#
#
# Initial guess [912, 355, 93291, 63, 10, 27]
# Fixed Points:
# H = 840.672476160964, C = 64.06289645193243, M = 21615.10560334646, N = 31.725232954143877, D = 1.000160813850851, R = 67.27460623200527
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [607, 234, 83859, 85, 9, 6]
# Fixed Points:
# H = -51.44949904719886, C = -1.075569206605847, M = -901.6839144155845, N = 101.53855395394213, D = 1.4710518801692714, R = -3.01875139329185
#
# Eigenvalues of the Jacobian: [-1.12905939e+00+1.24957705j -1.12905939e+00-1.24957705j
#  -9.11512516e-01+0.j         -8.54886254e-01+0.j
#   1.48453855e-05+0.j         -1.28608578e-01+0.j        ]
#
# The fixed point is unstable.
#
#
#
# Initial guess [1011, 403, 94952, 11, 71, 18]
# Fixed Points:
# H = 840.6724761609644, C = 64.06289645193247, M = 21615.105603346463, N = 31.72523295414386, D = 1.0001608138508513, R = 67.27460623200528
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [2123, 47, 33039, 80, 3, 17]
# Fixed Points:
# H = -51.449616743396824, C = -1.075574014510001, M = -901.6869145190071, N = 101.53856914082517, D = 1.4710503763484952, R = -3.018765121919024
#
# Eigenvalues of the Jacobian: [-1.12905827e+00+1.24957877j -1.12905827e+00-1.24957877j
#  -9.11512736e-01+0.j         -8.54886254e-01+0.j
#   1.23279916e-05+0.j         -1.28608260e-01+0.j        ]
#
# The fixed point is unstable.
#
#
#
# Initial guess [4173, 139, 23128, 44, 42, 14]
# Fixed Points:
# H = -16.329263840147032, C = -36.53768770833307, M = -12.083262646623673, N = -311.54886888273154, D = 34.75223645382952, R = 376.79663242890206
#
# Eigenvalues of the Jacobian: [25.8656119 +0.j         -2.97720617+0.j          0.38851854+0.j
#  -0.38642647+0.j         -0.8365514 +0.00640688j -0.8365514 -0.00640688j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [2530, 159, 40019, 61, 34, 5]
# Fixed Points:
# H = -16.329263840147036, C = -36.53768770833307, M = -12.083262646623766, N = -311.54886888273154, D = 34.75223645382951, R = 376.796632428902
#
# Eigenvalues of the Jacobian: [25.8656119 +0.j         -2.97720617+0.j          0.38851854+0.j
#  -0.38642647+0.j         -0.8365514 +0.00640688j -0.8365514 -0.00640688j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [1445, 301, 68847, 78, 16, 6]
# Fixed Points:
# H = -51.44978003551599, C = -1.0755854309208395, M = -901.6909914230132, N = 101.53859630357194, D = 1.4710483320224952, R = -3.018790455162366
#
# Eigenvalues of the Jacobian: [-1.12905673e+00+1.24958123j -1.12905673e+00-1.24958123j
#  -9.11513028e-01+0.j         -8.54886253e-01+0.j
#   8.83163957e-06+0.j         -1.28607747e-01+0.j        ]
#
# The fixed point is unstable.
#
#
#
# Initial guess [3781, 286, 13999, 65, 11, 24]
# Fixed Points:
# H = -51.45028401905995, C = -1.0756145730232027, M = -901.7038164033156, N = 101.53880551730322, D = 1.4710419002824948, R = -3.018991765989017
#
# Eigenvalues of the Jacobian: [-1.12905164e+00+1.24958976j -1.12905164e+00-1.24958976j
#  -9.11513995e-01+0.j         -8.54886252e-01+0.j
#  -2.60710360e-06+0.j         -1.28606196e-01+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [3806, 281, 44783, 96, 0, 4]
# Fixed Points:
# H = 30.242827563638638, C = 5.367869344884666, M = 1163.5513006242797, N = 83.62201011624074, D = 0.6687055933220535, R = 15.696425277686497
#
# Eigenvalues of the Jacobian: [-2.48498685e+00+0.j -1.27529220e+00+0.j -8.54264383e-01+0.j
#  -7.49545975e-01+0.j  2.67645384e-06+0.j -9.77700206e-02+0.j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [2832, 140, 28896, 66, 9, 25]
# Fixed Points:
# H = -51.450097510181735, C = -1.0755986561790178, M = -901.6990038976043, N = 101.53856340315522, D = 1.471044312634145, R = -3.0187547468077827
#
# Eigenvalues of the Jacobian: [-1.12905387e+00+1.24958529j -1.12905387e+00-1.24958529j
#  -9.11513592e-01+0.j         -8.54886253e-01+0.j
#   2.40279094e-06+0.j         -1.28606916e-01+0.j        ]
#
# The fixed point is unstable.
#
#
#
# Initial guess [1700, 94, 69283, 68, 19, 13]
# Fixed Points:
# H = -16.329263840147032, C = -36.53768770833307, M = -12.083262646623673, N = -311.5488688827316, D = 34.75223645382952, R = 376.79663242890206
#
# Eigenvalues of the Jacobian: [25.8656119 +0.j         -2.97720617+0.j          0.38851854+0.j
#  -0.38642647+0.j         -0.8365514 +0.00640688j -0.8365514 -0.00640688j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [545, 149, 63100, 80, 8, 12]
# Fixed Points:
# H = -51.449801531436485, C = -1.0755859167697324, M = -901.6914818698825, N = 101.53852821594872, D = 1.4710480821091076, R = -3.0187231380409894
#
# Eigenvalues of the Jacobian: [-1.12905669e+00+1.24958099j -1.12905669e+00-1.24958099j
#  -9.11513044e-01+0.j         -8.54886253e-01+0.j
#   8.70713211e-06+0.j         -1.28607724e-01+0.j        ]
#
# The fixed point is unstable.
#
#
#
# Initial guess [3779, 145, 26257, 84, 4, 12]
# Fixed Points:
# H = -51.450227574977916, C = -1.075611409129881, M = -901.7023729744305, N = 101.5387827434363, D = 1.4710426257925233, R = -3.018969877808602
#
# Eigenvalues of the Jacobian: [-1.12905221e+00+1.24958881j -1.12905221e+00-1.24958881j
#  -9.11513886e-01+0.j         -8.54886252e-01+0.j
#  -1.32135258e-06+0.j         -1.28606369e-01+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [734, 300, 84381, 62, 27, 11]
# Fixed Points:
# H = -16.329263840147036, C = -36.53768770833307, M = -12.083262646623675, N = -311.5488688827315, D = 34.75223645382951, R = 376.79663242890194
#
# Eigenvalues of the Jacobian: [25.8656119 +0.j         -2.97720617+0.j          0.38851854+0.j
#  -0.38642647+0.j         -0.8365514 +0.00640688j -0.8365514 -0.00640688j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [2302, 194, 1844, 89, 3, 8]
# Fixed Points:
# H = -51.45007187605538, C = -1.075600075350714, M = -901.6982956217934, N = 101.53855289693122, D = 1.4710446659000687, R = -3.018744813724377
#
# Eigenvalues of the Jacobian: [-1.12905415e+00+1.24958488j -1.12905415e+00-1.24958488j
#  -9.11513534e-01+0.j         -8.54886252e-01+0.j
#   2.99887642e-06+0.j         -1.28606953e-01+0.j        ]
#
# The fixed point is unstable.
#
#
#
# Initial guess [480, 105, 76381, 5, 79, 16]
# Fixed Points:
# H = 840.672476160964, C = 64.06289645193243, M = 21615.105603346456, N = 31.725232954143873, D = 1.000160813850851, R = 67.27460623200528
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [4311, 148, 17288, 43, 4, 53]
# Fixed Points:
# H = -51.45032765921135, C = -1.0756181699914933, M = -901.7049462876108, N = 101.53886533472857, D = 1.4710413311841528, R = -3.019050334065294
#
# Eigenvalues of the Jacobian: [-1.12905111e+00+1.24959083j -1.12905111e+00-1.24959083j
#  -9.11514091e-01+0.j         -8.54886251e-01+0.j
#  -3.79586524e-06+0.j         -1.28606028e-01+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [2161, 191, 63918, 6, 57, 37]
# Fixed Points:
# H = 840.6724761609644, C = 64.06289645193246, M = 21615.105603346463, N = 31.725232954143866, D = 1.000160813850851, R = 67.27460623200528
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [3445, 158, 33692, 66, 33, 1]
# Fixed Points:
# H = -16.329263840147032, C = -36.53768770833307, M = -12.083262646623671, N = -311.54886888273165, D = 34.75223645382952, R = 376.7966324289021
#
# Eigenvalues of the Jacobian: [25.8656119 +0.j         -2.97720617+0.j          0.38851854+0.j
#  -0.38642647+0.j         -0.8365514 +0.00640688j -0.8365514 -0.00640688j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [3474, 273, 80924, 77, 0, 23]
# Fixed Points:
# H = -51.44970296661799, C = -1.0755800203478114, M = -901.688984764846, N = 101.53849434633418, D = 1.4710493324680354, R = -3.0186906939567173
#
# Eigenvalues of the Jacobian: [-1.12905767e+00+1.24957937j -1.12905767e+00-1.24957937j
#  -9.11512858e-01+0.j         -8.54886254e-01+0.j
#   1.09068179e-05+0.j         -1.28608027e-01+0.j        ]
#
# The fixed point is unstable.
#
#
#
# Initial guess [2024, 378, 55308, 61, 13, 26]
# Fixed Points:
# H = 30.242963739592632, C = 5.36787827069163, M = 1163.5547384791892, N = 83.6219841018363, D = 0.6687066281885097, R = 15.696450183262309
#
# Eigenvalues of the Jacobian: [-2.48498952e+00+0.j -1.27529162e+00+0.j -8.54264383e-01+0.j
#  -7.49545799e-01+0.j  4.96419093e-06+0.j -9.77707434e-02+0.j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [757, 271, 43424, 70, 20, 10]
# Fixed Points:
# H = -51.45003203606186, C = -1.0755966851969698, M = -901.6973791803052, N = 101.53861636071468, D = 1.4710451297365397, R = -3.018807637574363
#
# Eigenvalues of the Jacobian: [-1.12905436e+00+1.24958482j -1.12905436e+00-1.24958482j
#  -9.11513490e-01+0.j         -8.54886253e-01+0.j
#   3.51260706e-06+0.j         -1.28607057e-01+0.j        ]
#
# The fixed point is unstable.
#
#
#
# Initial guess [560, 366, 16533, 93, 4, 3]
# Fixed Points:
# H = -51.44985177643338, C = -1.0755875989284394, M = -901.6927204972936, N = 101.53848978083998, D = 1.4710474566295262, R = -3.018684732237658
#
# Eigenvalues of the Jacobian: [-1.12905631e+00+1.24958137j -1.12905631e+00-1.24958137j
#  -9.11513121e-01+0.j         -8.54886253e-01+0.j
#   7.85097855e-06+0.j         -1.28607614e-01+0.j        ]
#
# The fixed point is unstable.
#
#
#
# Initial guess [3508, 55, 68984, 42, 40, 18]
# Fixed Points:
# H = -51.44923930406162, C = -1.0755500932982387, M = -901.6773868524051, N = 101.53845539033524, D = 1.4710551518686141, R = -3.0186565174014954
#
# Eigenvalues of the Jacobian: [-1.12906196e+00+1.24957271j -1.12906196e+00-1.24957271j
#  -9.11512032e-01+0.j         -8.54886256e-01+0.j
#   2.06769506e-05+0.j         -1.28609433e-01+0.j        ]
#
# The fixed point is unstable.
#
#
#
# Initial guess [382, 132, 51641, 23, 46, 31]
# Fixed Points:
# H = -16.329263840147032, C = -36.53768770833306, M = -12.083262646623671, N = -311.5488688827316, D = 34.752236453829525, R = 376.79663242890206
#
# Eigenvalues of the Jacobian: [25.8656119 +0.j         -2.97720617+0.j          0.38851854+0.j
#  -0.38642647+0.j         -0.8365514 +0.00640688j -0.8365514 -0.00640688j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [1547, 193, 80019, 75, 3, 22]
# Fixed Points:
# H = -51.45047190554665, C = -1.0756264304461831, M = -901.7084829911843, N = 101.53878823877899, D = 1.4710395641560035, R = -3.0189730403747452
#
# Eigenvalues of the Jacobian: [-1.12904998e+00+1.2495922j -1.12904998e+00-1.2495922j
#  -9.11514317e-01+0.j        -8.54886250e-01+0.j
#  -6.39629619e-06+0.j        -1.28605646e-01+0.j       ]
#
# The fixed point is stable.
#
#
#
# Initial guess [2114, 78, 31178, 34, 21, 45]
# Fixed Points:
# H = 30.242661766678605, C = 5.367859561442639, M = 1163.5471217694487, N = 83.62201667858514, D = 0.6687043348500498, R = 15.696419662447518
#
# Eigenvalues of the Jacobian: [-2.48498344e+00+0.j -1.27529293e+00+0.j -8.54264382e-01+0.j
#  -7.49546196e-01+0.j -3.22909655e-07+0.j -9.77690596e-02+0.j]
#
# The fixed point is stable.
#
#
#
# Initial guess [2893, 359, 85297, 54, 28, 18]
# Fixed Points:
# H = 840.6724761609642, C = 64.06289645193246, M = 21615.10560334646, N = 31.72523295414387, D = 1.0001608138508513, R = 67.27460623200528
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [907, 425, 87965, 59, 28, 13]
# Fixed Points:
# H = -16.329263840147032, C = -36.53768770833306, M = -12.083262646623673, N = -311.5488688827316, D = 34.75223645382952, R = 376.7966324289021
#
# Eigenvalues of the Jacobian: [25.8656119 +0.j         -2.97720617+0.j          0.38851854+0.j
#  -0.38642647+0.j         -0.8365514 +0.00640688j -0.8365514 -0.00640688j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [1095, 356, 25097, 58, 37, 5]
# Fixed Points:
# H = 840.6724761609642, C = 64.06289645193246, M = 21615.105603346463, N = 31.725232954143866, D = 1.000160813850851, R = 67.27460623200528
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [2888, 148, 50199, 87, 2, 11]
# Fixed Points:
# H = 30.243082822799455, C = 5.367886142639446, M = 1163.5577450715564, N = 83.62196008240923, D = 0.6687075332154391, R = 15.696473213164023
#
# Eigenvalues of the Jacobian: [-2.48499185e+00+0.j -1.27529111e+00+0.j -8.54264384e-01+0.j
#  -7.49545645e-01+0.j  6.95365557e-06+0.j -9.77713712e-02+0.j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [2613, 294, 80752, 42, 9, 49]
# Fixed Points:
# H = -51.45046660132968, C = -1.0756284989831482, M = -901.7083945599194, N = 101.53888000240924, D = 1.4710396057434802, R = -3.019063613038053
#
# Eigenvalues of the Jacobian: [-1.12904983e+00+1.24959285j -1.12904983e+00-1.24959285j
#  -9.11514334e-01+0.j         -8.54886250e-01+0.j
#  -6.72284334e-06+0.j         -1.28605586e-01+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [521, 263, 22433, 46, 0, 54]
# Fixed Points:
# H = 840.672476160964, C = 64.06289645193243, M = 21615.105603346456, N = 31.725232954143873, D = 1.000160813850851, R = 67.27460623200528
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [1935, 332, 16494, 3, 64, 33]
# Fixed Points:
# H = 840.6724761609643, C = 64.06289645193243, M = 21615.105603346467, N = 31.725232954143873, D = 1.0001608138508509, R = 67.27460623200527
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [3562, 89, 53482, 83, 1, 16]
# Fixed Points:
# H = 840.6724761609643, C = 64.06289645193246, M = 21615.105603346463, N = 31.725232954143863, D = 1.0001608138508513, R = 67.27460623200528
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [670, 336, 47605, 66, 11, 23]
# Fixed Points:
# H = 840.6724761609661, C = 64.06289645193257, M = 21615.105603346507, N = 31.72523295414375, D = 1.000160813850851, R = 67.2746062320054
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [4089, 317, 42253, 43, 36, 21]
# Fixed Points:
# H = -16.329263840147032, C = -36.53768770833307, M = -12.083262646623673, N = -311.5488688827315, D = 34.75223645382952, R = 376.796632428902
#
# Eigenvalues of the Jacobian: [25.8656119 +0.j         -2.97720617+0.j          0.38851854+0.j
#  -0.38642647+0.j         -0.8365514 +0.00640688j -0.8365514 -0.00640688j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [3588, 212, 97105, 42, 54, 4]
# Fixed Points:
# H = 840.6724761609642, C = 64.06289645193245, M = 21615.105603346456, N = 31.72523295414387, D = 1.0001608138508513, R = 67.27460623200528
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [2346, 147, 27263, 58, 14, 28]
# Fixed Points:
# H = -16.329263840147025, C = -36.53768770833306, M = -12.083262646623423, N = -311.5488688827316, D = 34.75223645382952, R = 376.7966324289021
#
# Eigenvalues of the Jacobian: [25.8656119 +0.j         -2.97720617+0.j          0.38851854+0.j
#  -0.38642647+0.j         -0.8365514 +0.00640688j -0.8365514 -0.00640688j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [723, 426, 34289, 98, 2, 0]
# Fixed Points:
# H = -51.45033760013884, C = -1.0756147114420105, M = -901.7049901011867, N = 101.5385806510013, D = 1.471041306619887, R = -3.018769598008658
#
# Eigenvalues of the Jacobian: [-1.12905166e+00+1.24958873j -1.12905166e+00-1.24958873j
#  -9.11514016e-01+0.j         -8.54886251e-01+0.j
#  -2.63501190e-06+0.j         -1.28606182e-01+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [959, 195, 99854, 3, 1, 96]
# Fixed Points:
# H = 840.6724761609646, C = 64.06289645193247, M = 21615.105603346467, N = 31.725232954143863, D = 1.000160813850851, R = 67.27460623200528
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [4072, 443, 96987, 74, 26, 0]
# Fixed Points:
# H = 840.6724761609638, C = 64.06289645193242, M = 21615.105603346456, N = 31.72523295414388, D = 1.000160813850851, R = 67.27460623200527
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [1096, 178, 60547, 86, 10, 4]
# Fixed Points:
# H = 30.242921284751766, C = 5.36787550834039, M = 1163.5536640290595, N = 83.62199592432702, D = 0.66870630510205, R = 15.696438773802678
#
# Eigenvalues of the Jacobian: [-2.48498871e+00+0.j -1.27529180e+00+0.j -8.54264383e-01+0.j
#  -7.49545853e-01+0.j  4.27855414e-06+0.j -9.77705271e-02+0.j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [365, 431, 53710, 18, 35, 47]
# Fixed Points:
# H = 840.6724761609646, C = 64.06289645193247, M = 21615.105603346467, N = 31.725232954143866, D = 1.000160813850851, R = 67.27460623200528
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [564, 4, 32316, 39, 14, 47]
# Fixed Points:
# H = 30.24211885419718, C = 5.367824792410633, M = 1163.5334214707227, N = 83.6221001689146, D = 0.6687002103056517, R = 15.696340265870212
#
# Eigenvalues of the Jacobian: [-2.48497264e+00+0.j -1.27529526e+00+0.j -8.54264379e-01+0.j
#  -7.49546904e-01+0.j -9.61537562e-06+0.j -9.77661130e-02+0.j]
#
# The fixed point is stable.
#
#
#
# Initial guess [3793, 186, 40473, 89, 9, 2]
# Fixed Points:
# H = -51.45060256182724, C = -1.0756317599569905, M = -901.7118396637161, N = 101.53883283946286, D = 1.4710378800395236, R = -3.0190156032401343
#
# Eigenvalues of the Jacobian: [-1.12904866e+00+1.24959433j -1.12904866e+00-1.24959433j
#  -9.11514571e-01+0.j         -8.54886251e-01+0.j
#  -9.32626156e-06+0.j         -1.28605280e-01+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [1332, 40, 67961, 78, 4, 18]
# Fixed Points:
# H = 30.242245374175287, C = 5.3678326488758055, M = 1163.5366121651023, N = 83.62208704995055, D = 0.6687011706278092, R = 15.69635253412441
#
# Eigenvalues of the Jacobian: [-2.48497520e+00+0.j -1.27529471e+00+0.j -8.54264380e-01+0.j
#  -7.49546737e-01+0.j -7.39700635e-06+0.j -9.77668195e-02+0.j]
#
# The fixed point is stable.
#
#
#
# Initial guess [4092, 296, 3731, 48, 26, 26]
# Fixed Points:
# H = -16.329263840147036, C = -36.53768770833307, M = -12.083262646623675, N = -311.5488688827315, D = 34.75223645382951, R = 376.796632428902
#
# Eigenvalues of the Jacobian: [25.8656119 +0.j         -2.97720617+0.j          0.38851854+0.j
#  -0.38642647+0.j         -0.8365514 +0.00640688j -0.8365514 -0.00640688j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [778, 156, 98710, 29, 58, 13]
# Fixed Points:
# H = -16.329263840147032, C = -36.53768770833307, M = -12.083262646623673, N = -311.54886888273154, D = 34.75223645382952, R = 376.79663242890206
#
# Eigenvalues of the Jacobian: [25.8656119 +0.j         -2.97720617+0.j          0.38851854+0.j
#  -0.38642647+0.j         -0.8365514 +0.00640688j -0.8365514 -0.00640688j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [269, 404, 65810, 11, 14, 75]
# Fixed Points:
# H = 30.24276489288268, C = 5.367865621829044, M = 1163.549719210676, N = 83.622015624723, D = 0.6687051170152101, R = 15.696420180622965
#
# Eigenvalues of the Jacobian: [-2.48498558e+00+0.j -1.27529247e+00+0.j -8.54264382e-01+0.j
#  -7.49546058e-01+0.j  1.56576538e-06+0.j -9.77696652e-02+0.j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [3912, 194, 50957, 100, 0, 0]
# Fixed Points:
# H = 30.242001769597362, C = 5.36781783024103, M = 1163.5304729925986, N = 83.62210146188886, D = 0.6686993248013442, R = 15.696339576960757
#
# Eigenvalues of the Jacobian: [-2.48497022e+00+0.j -1.27529578e+00+0.j -8.54264378e-01+0.j
#  -7.49547061e-01+0.j -1.17541979e-05+0.j -9.77654282e-02+0.j]
#
# The fixed point is stable.
#
#
#
# Initial guess [754, 44, 75741, 32, 6, 62]
# Fixed Points:
# H = -51.44989873258908, C = -1.0755841593253037, M = -901.693981076724, N = 101.53845642046478, D = 1.4710468260544114, R = -3.018651061938312
#
# Eigenvalues of the Jacobian: [-1.12905591e+00+1.24958173j -1.12905591e+00-1.24958173j
#  -9.11513211e-01+0.j         -8.54886254e-01+0.j
#   7.01065527e-06+0.j         -1.28607581e-01+0.j        ]
#
# The fixed point is unstable.
#
#
#
# Initial guess [1050, 367, 72927, 70, 17, 13]
# Fixed Points:
# H = -51.451047072300895, C = -1.0756575445820609, M = -901.7230226780011, N = 101.53888854056163, D = 1.4710322750770692, R = -3.019066281718227
#
# Eigenvalues of the Jacobian: [-1.12904447e+00+1.24960085j -1.12904447e+00-1.24960085j
#  -9.11515377e-01+0.j         -8.54886249e-01+0.j
#  -1.87838945e-05+0.j         -1.28603968e-01+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [218, 439, 66555, 82, 3, 15]
# Fixed Points:
# H = 30.242755117568496, C = 5.367864683456271, M = 1163.5494719850733, N = 83.62202223390342, D = 0.6687050427900834, R = 15.696413722906408
#
# Eigenvalues of the Jacobian: [-2.48498541e+00+0.j -1.27529251e+00+0.j -8.54264382e-01+0.j
#  -7.49546069e-01+0.j  1.44430545e-06+0.j -9.77696302e-02+0.j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [3710, 243, 51777, 72, 16, 12]
# Fixed Points:
# H = -16.329263840147032, C = -36.53768770833306, M = -12.08326264662367, N = -311.5488688827316, D = 34.75223645382952, R = 376.79663242890206
#
# Eigenvalues of the Jacobian: [25.8656119 +0.j         -2.97720617+0.j          0.38851854+0.j
#  -0.38642647+0.j         -0.8365514 +0.00640688j -0.8365514 -0.00640688j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [3721, 448, 26081, 61, 14, 25]
# Fixed Points:
# H = -16.32926384014703, C = -36.53768770833306, M = -12.083262646623671, N = -311.5488688827316, D = 34.75223645382952, R = 376.7966324289021
#
# Eigenvalues of the Jacobian: [25.8656119 +0.j         -2.97720617+0.j          0.38851854+0.j
#  -0.38642647+0.j         -0.8365514 +0.00640688j -0.8365514 -0.00640688j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [4400, 193, 33063, 13, 4, 83]
# Fixed Points:
# H = -51.45010520002347, C = -1.0755965130573475, M = -901.69918336633, N = 101.53849732090518, D = 1.4710442181378336, R = -3.018689425291455
#
# Eigenvalues of the Jacobian: [-1.12905393e+00+1.24958487j -1.12905393e+00-1.24958487j
#  -9.11513589e-01+0.j         -8.54886254e-01+0.j
#   2.54583729e-06+0.j         -1.28606960e-01+0.j        ]
#
# The fixed point is unstable.
#
#
#
# Initial guess [2339, 84, 80856, 36, 43, 21]
# Fixed Points:
# H = -16.32926384014703, C = -36.53768770833306, M = -12.083262646623671, N = -311.54886888273154, D = 34.75223645382952, R = 376.79663242890206
#
# Eigenvalues of the Jacobian: [25.8656119 +0.j         -2.97720617+0.j          0.38851854+0.j
#  -0.38642647+0.j         -0.8365514 +0.00640688j -0.8365514 -0.00640688j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [826, 367, 54059, 60, 6, 34]
# Fixed Points:
# H = 840.6724761609644, C = 64.06289645193246, M = 21615.105603346463, N = 31.725232954143866, D = 1.000160813850851, R = 67.27460623200528
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [676, 242, 28575, 2, 89, 9]
# Fixed Points:
# H = 840.6724761609646, C = 64.06289645193247, M = 21615.10560334647, N = 31.725232954143863, D = 1.000160813850851, R = 67.27460623200528
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [891, 37, 72169, 54, 31, 15]
# Fixed Points:
# H = -16.329263840147036, C = -36.53768770833306, M = -12.083262646623677, N = -311.5488688827315, D = 34.75223645382951, R = 376.79663242890194
#
# Eigenvalues of the Jacobian: [25.8656119 +0.j         -2.97720617+0.j          0.38851854+0.j
#  -0.38642647+0.j         -0.8365514 +0.00640688j -0.8365514 -0.00640688j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [2344, 91, 31592, 12, 31, 57]
# Fixed Points:
# H = 840.6724761609645, C = 64.06289645193246, M = 21615.105603346467, N = 31.725232954143866, D = 1.000160813850851, R = 67.27460623200528
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [887, 412, 91593, 6, 0, 94]
# Fixed Points:
# H = 840.672476160964, C = 64.06289645193243, M = 21615.105603346456, N = 31.725232954143873, D = 1.000160813850851, R = 67.27460623200527
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [1603, 176, 11584, 64, 28, 8]
# Fixed Points:
# H = 30.24281986788388, C = 5.367870596152393, M = 1163.5511184273744, N = 83.62196963343439, D = 0.6687055397992256, R = 15.696465145361364
#
# Eigenvalues of the Jacobian: [-2.48498644e+00+0.j -1.27529227e+00+0.j -8.54264382e-01+0.j
#  -7.49545996e-01+0.j  2.19406323e-06+0.j -9.77698469e-02+0.j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [3912, 180, 7340, 5, 46, 49]
# Fixed Points:
# H = 30.242010482180806, C = 5.367817670071607, M = 1163.5306848686519, N = 83.62212209058788, D = 0.6686993861382978, R = 15.696319248091443
#
# Eigenvalues of the Jacobian: [-2.48497052e+00+0.j -1.27529572e+00+0.j -8.54264379e-01+0.j
#  -7.49547044e-01+0.j -1.14271853e-05+0.j -9.77655407e-02+0.j]
#
# The fixed point is stable.
#
#
#
# Initial guess [3496, 159, 25376, 46, 16, 38]
# Fixed Points:
# H = -16.329263840147032, C = -36.53768770833307, M = -12.083262646623671, N = -311.54886888273165, D = 34.752236453829525, R = 376.7966324289021
#
# Eigenvalues of the Jacobian: [25.8656119 +0.j         -2.97720617+0.j          0.38851854+0.j
#  -0.38642647+0.j         -0.8365514 +0.00640688j -0.8365514 -0.00640688j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [1515, 306, 75404, 32, 54, 14]
# Fixed Points:
# H = 840.6724761609646, C = 64.06289645193247, M = 21615.105603346467, N = 31.725232954143856, D = 1.000160813850851, R = 67.2746062320053
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [2758, 442, 93617, 50, 47, 3]
# Fixed Points:
# H = 840.6724761609643, C = 64.06289645193245, M = 21615.105603346467, N = 31.72523295414387, D = 1.000160813850851, R = 67.27460623200528
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [1353, 369, 41435, 19, 65, 16]
# Fixed Points:
# H = 840.6724761609643, C = 64.06289645193245, M = 21615.10560334646, N = 31.72523295414387, D = 1.000160813850851, R = 67.27460623200528
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [794, 417, 93243, 27, 43, 30]
# Fixed Points:
# H = -16.329263840147032, C = -36.53768770833306, M = -12.083262646623671, N = -311.5488688827316, D = 34.75223645382952, R = 376.79663242890206
#
# Eigenvalues of the Jacobian: [25.8656119 +0.j         -2.97720617+0.j          0.38851854+0.j
#  -0.38642647+0.j         -0.8365514 +0.00640688j -0.8365514 -0.00640688j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [3586, 40, 87197, 48, 43, 9]
# Fixed Points:
# H = 840.6724761609642, C = 64.06289645193245, M = 21615.105603346463, N = 31.72523295414387, D = 1.000160813850851, R = 67.27460623200528
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [3836, 221, 98488, 64, 29, 7]
# Fixed Points:
# H = -16.329263840147032, C = -36.53768770833305, M = -12.083262646623671, N = -311.5488688827316, D = 34.75223645382952, R = 376.79663242890206
#
# Eigenvalues of the Jacobian: [25.8656119 +0.j         -2.97720617+0.j          0.38851854+0.j
#  -0.38642647+0.j         -0.8365514 +0.00640688j -0.8365514 -0.00640688j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [4372, 278, 95227, 74, 25, 1]
# Fixed Points:
# H = 840.6724761609644, C = 64.06289645193246, M = 21615.105603346463, N = 31.725232954143866, D = 1.000160813850851, R = 67.27460623200528
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [1624, 19, 91272, 62, 1, 37]
# Fixed Points:
# H = -51.45058774461686, C = -1.0756311230692743, M = -901.7114372419213, N = 101.53880341133977, D = 1.4710380828383127, R = -3.018986771228582
#
# Eigenvalues of the Jacobian: [-1.12904886e+00+1.24959389j -1.12904886e+00-1.24959389j
#  -9.11514534e-01+0.j         -8.54886250e-01+0.j
#  -8.87626613e-06+0.j         -1.28605333e-01+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [2470, 91, 14063, 79, 6, 15]
# Fixed Points:
# H = -51.45042564379821, C = -1.0756218502327992, M = -901.7073906383042, N = 101.53881979861339, D = 1.4710401092777394, R = -3.0190044448204914
#
# Eigenvalues of the Jacobian: [-1.12905031e+00+1.2495918j -1.12905031e+00-1.2495918j
#  -9.11514253e-01+0.j        -8.54886251e-01+0.j
#  -5.60482426e-06+0.j        -1.28605793e-01+0.j       ]
#
# The fixed point is stable.
#
#
#
# Initial guess [1656, 2, 35205, 23, 37, 40]
# Fixed Points:
# H = -51.4506199832976, C = -1.0756347073844743, M = -901.7122171931201, N = 101.53880984762331, D = 1.4710376921560948, R = -3.0189929109390805
#
# Eigenvalues of the Jacobian: [-1.12904857e+00+1.24959439j -1.12904857e+00-1.24959439j
#  -9.11514588e-01+0.j         -8.54886250e-01+0.j
#  -9.56363075e-06+0.j         -1.28605212e-01+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [2293, 89, 63182, 36, 25, 39]
# Fixed Points:
# H = 840.672476160964, C = 64.06289645193243, M = 21615.10560334646, N = 31.725232954143873, D = 1.000160813850851, R = 67.27460623200527
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [1788, 17, 86238, 67, 28, 5]
# Fixed Points:
# H = -16.329263840147032, C = -36.53768770833307, M = -12.083262646623675, N = -311.54886888273154, D = 34.75223645382951, R = 376.79663242890206
#
# Eigenvalues of the Jacobian: [25.8656119 +0.j         -2.97720617+0.j          0.38851854+0.j
#  -0.38642647+0.j         -0.8365514 +0.00640688j -0.8365514 -0.00640688j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [984, 205, 22927, 54, 31, 15]
# Fixed Points:
# H = -51.449278978237295, C = -1.0755565995893566, M = -901.678362171939, N = 101.53851281364938, D = 1.471054663687071, R = -3.018712953729074
#
# Eigenvalues of the Jacobian: [-1.12906150e+00+1.24957372j -1.12906150e+00-1.24957372j
#  -9.11512112e-01+0.j         -8.54886255e-01+0.j
#   1.95943736e-05+0.j         -1.28609231e-01+0.j        ]
#
# The fixed point is unstable.
#
#
#
# Initial guess [1080, 0, 71713, 60, 2, 38]
# Fixed Points:
# H = 30.242628386698968, C = 5.367857418673203, M = 1163.5462807230263, N = 83.62201983520794, D = 0.6687040818010134, R = 15.696416721610863
#
# Eigenvalues of the Jacobian: [-2.48498276e+00+0.j -1.27529307e+00+0.j -8.54264381e-01+0.j
#  -7.49546240e-01+0.j -9.08661099e-07+0.j -9.77688738e-02+0.j]
#
# The fixed point is stable.
#
#
#
# Initial guess [2840, 330, 54482, 90, 7, 3]
# Fixed Points:
# H = 30.242204447492078, C = 5.367830720935613, M = 1163.5355880766783, N = 83.62207076865502, D = 0.6687008645060387, R = 15.696368746690196
#
# Eigenvalues of the Jacobian: [-2.48497425e+00+0.j -1.27529491e+00+0.j -8.54264379e-01+0.j
#  -7.49546797e-01+0.j -8.27960634e-06+0.j -9.77665309e-02+0.j]
#
# The fixed point is stable.
#
#
#
# Initial guess [1014, 269, 25104, 30, 50, 20]
# Fixed Points:
# H = 840.6724761609643, C = 64.06289645193243, M = 21615.105603346463, N = 31.725232954143873, D = 1.0001608138508509, R = 67.27460623200527
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [1451, 325, 30685, 62, 26, 12]
# Fixed Points:
# H = -51.44964530764006, C = -1.0755713881611864, M = -901.6875730055398, N = 101.53843134284922, D = 1.4710500401359816, R = -3.018628866856392
#
# Eigenvalues of the Jacobian: [-1.12905830e+00+1.24957807j -1.12905830e+00-1.24957807j
#  -9.11512748e-01+0.j         -8.54886255e-01+0.j
#   1.23844084e-05+0.j         -1.28608299e-01+0.j        ]
#
# The fixed point is unstable.
#
#
#
# Initial guess [1236, 300, 35955, 55, 12, 33]
# Fixed Points:
# H = 840.6724761609644, C = 64.06289645193246, M = 21615.105603346467, N = 31.725232954143873, D = 1.000160813850851, R = 67.27460623200528
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [4493, 342, 90075, 14, 12, 74]
# Fixed Points:
# H = 30.24285943095454, C = 5.367871202990998, M = 1163.5521011127596, N = 83.62201315518634, D = 0.668705835208127, R = 15.696422132286548
#
# Eigenvalues of the Jacobian: [-2.48498753e+00+0.j -1.27529206e+00+0.j -8.54264383e-01+0.j
#  -7.49545931e-01+0.j  3.28652367e-06+0.j -9.77702167e-02+0.j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [4311, 38, 76814, 99, 0, 1]
# Fixed Points:
# H = 30.24280394054779, C = 5.367868311949611, M = 1163.5507065636416, N = 83.62200403933927, D = 0.6687054140855258, R = 15.696431379793696
#
# Eigenvalues of the Jacobian: [-2.48498632e+00+0.j -1.27529231e+00+0.j -8.54264382e-01+0.j
#  -7.49546008e-01+0.j  2.18770597e-06+0.j -9.77698600e-02+0.j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [3007, 146, 66939, 79, 9, 12]
# Fixed Points:
# H = 840.6724761609645, C = 64.06289645193246, M = 21615.105603346467, N = 31.725232954143863, D = 1.000160813850851, R = 67.27460623200528
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [3158, 232, 8053, 6, 54, 40]
# Fixed Points:
# H = 30.24227589839089, C = 5.36783589834862, M = 1163.5373921727355, N = 83.62205022964365, D = 0.668701408573018, R = 15.69638860102027
#
# Eigenvalues of the Jacobian: [-2.48497561e+00+0.j -1.27529461e+00+0.j -8.54264379e-01+0.j
#  -7.49546706e-01+0.j -7.14102556e-06+0.j -9.77668854e-02+0.j]
#
# The fixed point is stable.
#
#
#
# Initial guess [1338, 439, 89528, 78, 19, 3]
# Fixed Points:
# H = -51.449722372489504, C = -1.075582130063209, M = -901.6895381848265, N = 101.53858730419064, D = 1.4710490605963695, R = -3.0187821368622707
#
# Eigenvalues of the Jacobian: [-1.12905728e+00+1.24958037j -1.12905728e+00-1.24958037j
#  -9.11512923e-01+0.j         -8.54886253e-01+0.j
#   1.00674777e-05+0.j         -1.28607917e-01+0.j        ]
#
# The fixed point is unstable.
#
#
#
# Initial guess [3222, 126, 2993, 52, 19, 29]
# Fixed Points:
# H = -16.329263840147032, C = -36.53768770833307, M = -12.083262646623671, N = -311.5488688827316, D = 34.75223645382952, R = 376.79663242890206
#
# Eigenvalues of the Jacobian: [25.8656119 +0.j         -2.97720617+0.j          0.38851854+0.j
#  -0.38642647+0.j         -0.8365514 +0.00640688j -0.8365514 -0.00640688j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [3656, 307, 32698, 98, 2, 0]
# Fixed Points:
# H = -51.45053188342142, C = -1.0756296748482086, M = -901.7099985732274, N = 101.53879529132765, D = 1.4710388043672296, R = -3.018979406594269
#
# Eigenvalues of the Jacobian: [-1.12904941e+00+1.24959307j -1.12904941e+00-1.24959307j
#  -9.11514427e-01+0.j         -8.54886250e-01+0.j
#  -7.67427403e-06+0.j         -1.28605472e-01+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [23, 52, 92829, 21, 25, 54]
# Fixed Points:
# H = -16.329263840147032, C = -36.53768770833306, M = -12.083262646623671, N = -311.5488688827316, D = 34.75223645382952, R = 376.79663242890206
#
# Eigenvalues of the Jacobian: [25.8656119 +0.j         -2.97720617+0.j          0.38851854+0.j
#  -0.38642647+0.j         -0.8365514 +0.00640688j -0.8365514 -0.00640688j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [1146, 24, 89064, 24, 46, 30]
# Fixed Points:
# H = -16.329263840147032, C = -36.53768770833306, M = -12.083262646623673, N = -311.54886888273165, D = 34.75223645382952, R = 376.7966324289021
#
# Eigenvalues of the Jacobian: [25.8656119 +0.j         -2.97720617+0.j          0.38851854+0.j
#  -0.38642647+0.j         -0.8365514 +0.00640688j -0.8365514 -0.00640688j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [666, 395, 21981, 91, 8, 1]
# Fixed Points:
# H = 840.6724761609643, C = 64.06289645193247, M = 21615.10560334646, N = 31.725232954143863, D = 1.0001608138508513, R = 67.27460623200528
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [827, 233, 5743, 55, 30, 15]
# Fixed Points:
# H = -51.45015814251887, C = -1.0756028074835056, M = -901.700529632924, N = 101.53858167720875, D = 1.4710435489701743, R = -3.018772213284889
#
# Eigenvalues of the Jacobian: [-1.12905328e+00+1.24958627j -1.12905328e+00-1.24958627j
#  -9.11513704e-01+0.j         -8.54886253e-01+0.j
#   1.06296753e-06+0.j         -1.28606723e-01+0.j        ]
#
# The fixed point is unstable.
#
#
#
# Initial guess [860, 399, 53977, 82, 5, 13]
# Fixed Points:
# H = 30.242539275136128, C = 5.367852274785665, M = 1163.5440346441403, N = 83.62202187271028, D = 0.6687034064894577, R = 15.6964151704201
#
# Eigenvalues of the Jacobian: [-2.48498092e+00+0.j -1.27529346e+00+0.j -8.54264381e-01+0.j
#  -7.49546359e-01+0.j -2.53322222e-06+0.j -9.77683522e-02+0.j]
#
# The fixed point is stable.
#
#
#
# Initial guess [600, 408, 75358, 14, 16, 70]
# Fixed Points:
# H = 840.6724761609643, C = 64.06289645193245, M = 21615.105603346463, N = 31.725232954143866, D = 1.000160813850851, R = 67.27460623200528
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [844, 142, 95324, 60, 33, 7]
# Fixed Points:
# H = -16.329263840147032, C = -36.53768770833306, M = -12.083262646623675, N = -311.54886888273154, D = 34.75223645382951, R = 376.796632428902
#
# Eigenvalues of the Jacobian: [25.8656119 +0.j         -2.97720617+0.j          0.38851854+0.j
#  -0.38642647+0.j         -0.8365514 +0.00640688j -0.8365514 -0.00640688j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [4358, 323, 89395, 1, 42, 57]
# Fixed Points:
# H = 30.24266261948016, C = 5.367859600593595, M = 1163.547143166018, N = 83.6220169346587, D = 0.6687043412854042, R = 15.696419406227896
#
# Eigenvalues of the Jacobian: [-2.48498346e+00+0.j -1.27529292e+00+0.j -8.54264382e-01+0.j
#  -7.49546195e-01+0.j -3.05067706e-07+0.j -9.77690655e-02+0.j]
#
# The fixed point is stable.
#
#
#
# Initial guess [1083, 76, 19393, 54, 30, 16]
# Fixed Points:
# H = -51.450269743715154, C = -1.0756152246635071, M = -901.7033913143664, N = 101.53876287161299, D = 1.471042116126766, R = -3.0189499872278645
#
# Eigenvalues of the Jacobian: [-1.12905188e+00+1.24958923j -1.12905188e+00-1.24958923j
#  -9.11513950e-01+0.j         -8.54886251e-01+0.j
#  -2.09650732e-06+0.j         -1.28606235e-01+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [453, 121, 21304, 92, 2, 6]
# Fixed Points:
# H = 840.672476160964, C = 64.06289645193245, M = 21615.105603346456, N = 31.72523295414387, D = 1.0001608138508513, R = 67.27460623200528
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [4073, 153, 52288, 39, 49, 12]
# Fixed Points:
# H = -16.329263840147032, C = -36.53768770833305, M = -12.083262646623675, N = -311.54886888273154, D = 34.75223645382951, R = 376.79663242890206
#
# Eigenvalues of the Jacobian: [25.8656119 +0.j         -2.97720617+0.j          0.38851854+0.j
#  -0.38642647+0.j         -0.8365514 +0.00640688j -0.8365514 -0.00640688j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [3512, 339, 51118, 19, 48, 33]
# Fixed Points:
# H = 840.6724761609642, C = 64.06289645193245, M = 21615.105603346456, N = 31.725232954143873, D = 1.000160813850851, R = 67.27460623200528
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [3629, 296, 53952, 45, 8, 47]
# Fixed Points:
# H = -51.449961993535055, C = -1.075593727109076, M = -901.6956170284423, N = 101.53862756551914, D = 1.4710460134759946, R = -3.0188193993515067
#
# Eigenvalues of the Jacobian: [-1.12905498e+00+1.24958395j -1.12905498e+00-1.24958395j
#  -9.11513367e-01+0.j         -8.54886253e-01+0.j
#   4.91035230e-06+0.j         -1.28607239e-01+0.j        ]
#
# The fixed point is unstable.
#
#
#
# Initial guess [2291, 127, 10716, 80, 9, 11]
# Fixed Points:
# H = -51.449940005071, C = -1.0755926345318774, M = -901.695066444121, N = 101.53862746075129, D = 1.4710462897571441, R = -3.0188195127599173
#
# Eigenvalues of the Jacobian: [-1.12905518e+00+1.24958365j -1.12905518e+00-1.24958365j
#  -9.11513328e-01+0.j         -8.54886253e-01+0.j
#   5.36289848e-06+0.j         -1.28607300e-01+0.j        ]
#
# The fixed point is unstable.
#
#
#
# Initial guess [2255, 61, 89642, 4, 3, 93]
# Fixed Points:
# H = -51.44993867014622, C = -1.075594807236717, M = -901.6949702990761, N = 101.53860712989724, D = 1.4710463363233646, R = -3.018799634290898
#
# Eigenvalues of the Jacobian: [-1.12905526e+00+1.24958348j -1.12905526e+00-1.24958348j
#  -9.11513312e-01+0.j         -8.54886252e-01+0.j
#   5.50029156e-06+0.j         -1.28607280e-01+0.j        ]
#
# The fixed point is unstable.
#
#
#
# Initial guess [688, 261, 3918, 93, 5, 2]
# Fixed Points:
# H = 30.242325492615265, C = 5.367837881898751, M = 1163.5386346276864, N = 83.62207231134667, D = 0.6687017795736961, R = 15.696366629593953
#
# Eigenvalues of the Jacobian: [-2.48497678e+00+0.j -1.27529437e+00+0.j -8.54264380e-01+0.j
#  -7.49546634e-01+0.j -6.04606264e-06+0.j -9.77672467e-02+0.j]
#
# The fixed point is stable.
#
#
#
# Initial guess [3116, 305, 29095, 72, 13, 15]
# Fixed Points:
# H = 30.243547278134862, C = 5.367916071451388, M = 1163.5694649713478, N = 83.62188696728802, D = 0.6687110618895806, R = 15.696542803600408
#
# Eigenvalues of the Jacobian: [-2.48500108e+00+0.j -1.27528912e+00+0.j -8.54264386e-01+0.j
#  -7.49545040e-01+0.j  1.48857594e-05+0.j -9.77738841e-02+0.j]
#
# The fixed point is unstable.
#
#
#
# ...
#
# The fixed point is stable.
#
#
#
# Initial guess [1816, 305, 64930, 6, 78, 16]
# Fixed Points:
# H = 840.6724761609642, C = 64.06289645193243, M = 21615.105603346467, N = 31.725232954143873, D = 1.0001608138508509, R = 67.27460623200527
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [3933, 151, 86672, 39, 29, 32]
# Fixed Points:
# H = -51.45011068836441, C = -1.0755992436732111, M = -901.6993335467519, N = 101.5385573410197, D = 1.4710441469888484, R = -3.0187486396454934
#
# Eigenvalues of the Jacobian: [-1.12905376e+00+1.24958543j -1.12905376e+00-1.24958543j
#  -9.11513614e-01+0.j         -8.54886253e-01+0.j
#   2.15632723e-06+0.j         -1.28606883e-01+0.j        ]
#
# The fixed point is unstable.
#
#
#
# Initial guess [3863, 170, 1964, 22, 39, 39]
# Fixed Points:
# H = -16.329263840147036, C = -36.53768770833306, M = -12.083262646623677, N = -311.5488688827315, D = 34.75223645382951, R = 376.796632428902
#
# Eigenvalues of the Jacobian: [25.8656119 +0.j         -2.97720617+0.j          0.38851854+0.j
#  -0.38642647+0.j         -0.8365514 +0.00640688j -0.8365514 -0.00640688j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [349, 115, 10017, 2, 9, 89]
# Fixed Points:
# H = 30.24268451518882, C = 5.3678614113925285, M = 1163.5477002684468, N = 83.62200116489868, D = 0.6687045097680153, R = 15.696434805237176
#
# Eigenvalues of the Jacobian: [-2.48498381e+00+0.j -1.27529284e+00+0.j -8.54264381e-01+0.j
#  -7.49546169e-01+0.j -3.15548632e-08+0.j -9.77691471e-02+0.j]
#
# The fixed point is stable.
#
#
#
# Initial guess [4071, 441, 85957, 30, 38, 32]
# Fixed Points:
# H = 840.672476160964, C = 64.06289645193243, M = 21615.10560334646, N = 31.725232954143877, D = 1.000160813850851, R = 67.27460623200527
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [478, 307, 71669, 36, 8, 56]
# Fixed Points:
# H = 840.6724761609643, C = 64.06289645193245, M = 21615.105603346467, N = 31.725232954143873, D = 1.000160813850851, R = 67.27460623200528
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [315, 196, 18999, 48, 36, 16]
# Fixed Points:
# H = -16.329263840147032, C = -36.53768770833306, M = -12.083262646623673, N = -311.5488688827316, D = 34.75223645382952, R = 376.7966324289021
#
# Eigenvalues of the Jacobian: [25.8656119 +0.j         -2.97720617+0.j          0.38851854+0.j
#  -0.38642647+0.j         -0.8365514 +0.00640688j -0.8365514 -0.00640688j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [4366, 298, 91473, 48, 0, 52]
# Fixed Points:
# H = 840.6724761609644, C = 64.06289645193245, M = 21615.105603346467, N = 31.725232954143873, D = 1.0001608138508509, R = 67.27460623200528
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [1890, 202, 39966, 41, 55, 4]
# Fixed Points:
# H = -51.450896734456194, C = -1.0756489815255883, M = -901.7192204560313, N = 101.53885172349406, D = 1.471034181299323, R = -3.0190314436728816
#
# Eigenvalues of the Jacobian: [-1.12904593e+00+1.2495985j -1.12904593e+00-1.2495985j
#  -9.11515097e-01+0.j        -8.54886249e-01+0.j
#  -1.54969718e-05+0.j        -1.28604417e-01+0.j       ]
#
# The fixed point is stable.
#
#
#
# Initial guess [3841, 148, 68343, 15, 11, 74]
# Fixed Points:
# H = 30.24197048245808, C = 5.367815078417164, M = 1163.5296752488466, N = 83.6221289821548, D = 0.6686990821602795, R = 15.696312670147083
#
# Eigenvalues of the Jacobian: [-2.48496973e+00+0.j -1.27529589e+00+0.j -8.54264379e-01+0.j
#  -7.49547096e-01+0.j -1.21056548e-05+0.j -9.77653259e-02+0.j]
#
# The fixed point is stable.
#
#
#
# Initial guess [1163, 218, 7386, 68, 10, 22]
# Fixed Points:
# H = 30.24301446467716, C = 5.36788084608646, M = 1163.5560093773756, N = 83.62199899100864, D = 0.6687070138069261, R = 15.696435286932342
#
# Eigenvalues of the Jacobian: [-2.48499067e+00+0.j -1.27529138e+00+0.j -8.54264384e-01+0.j
#  -7.49545727e-01+0.j  6.02135133e-06+0.j -9.77710878e-02+0.j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [1592, 64, 98119, 40, 10, 50]
# Fixed Points:
# H = 30.24261292840399, C = 5.367857482696022, M = 1163.5459003258352, N = 83.62199315770988, D = 0.6687039710149851, R = 15.696443036383492
#
# Eigenvalues of the Jacobian: [-2.48498227e+00+0.j -1.27529316e+00+0.j -8.54264381e-01+0.j
#  -7.49546268e-01+0.j -1.41032490e-06+0.j -9.77687021e-02+0.j]
#
# The fixed point is stable.
#
#
#
# Initial guess [3997, 304, 81174, 93, 0, 7]
# Fixed Points:
# H = 30.242755276674977, C = 5.367866689674853, M = 1163.5494927552675, N = 83.62196951189594, D = 0.6687050526134369, R = 15.696465581251813
#
# Eigenvalues of the Jacobian: [-2.48498509e+00+0.j -1.27529255e+00+0.j -8.54264381e-01+0.j
#  -7.49546083e-01+0.j  1.01082986e-06+0.j -9.77694688e-02+0.j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [2187, 420, 85069, 58, 29, 13]
# Fixed Points:
# H = 840.6724761609645, C = 64.06289645193246, M = 21615.105603346467, N = 31.72523295414385, D = 1.000160813850851, R = 67.2746062320053
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [1573, 33, 92952, 28, 2, 70]
# Fixed Points:
# H = 840.6724761609643, C = 64.06289645193245, M = 21615.105603346467, N = 31.725232954143873, D = 1.0001608138508509, R = 67.27460623200528
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [4393, 80, 31070, 15, 41, 44]
# Fixed Points:
# H = -16.329263840147032, C = -36.53768770833307, M = -12.083262646623675, N = -311.54886888273154, D = 34.75223645382952, R = 376.79663242890206
#
# Eigenvalues of the Jacobian: [25.8656119 +0.j         -2.97720617+0.j          0.38851854+0.j
#  -0.38642647+0.j         -0.8365514 +0.00640688j -0.8365514 -0.00640688j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [2616, 385, 13245, 66, 10, 24]
# Fixed Points:
# H = 30.24292663172914, C = 5.367875118394967, M = 1163.5537959160845, N = 83.62200946963213, D = 0.6687063463763182, R = 15.69642541258915
#
# Eigenvalues of the Jacobian: [-2.48498890e+00+0.j -1.27529177e+00+0.j -8.54264383e-01+0.j
#  -7.49545842e-01+0.j  4.49671222e-06+0.j -9.77706049e-02+0.j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [2699, 303, 86376, 64, 17, 19]
# Fixed Points:
# H = 840.672476160964, C = 64.06289645193242, M = 21615.105603346463, N = 31.725232954143877, D = 1.0001608138508509, R = 67.27460623200527
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [571, 225, 42438, 65, 14, 21]
# Fixed Points:
# H = 30.242723425209174, C = 5.36786310657048, M = 1163.548674289443, N = 83.62201776744041, D = 0.6687048022473108, R = 15.696418280861018
#
# Eigenvalues of the Jacobian: [-2.48498473e+00+0.j -1.27529265e+00+0.j -8.54264382e-01+0.j
#  -7.49546113e-01+0.j  8.20848763e-07+0.j -9.77694272e-02+0.j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [938, 384, 92613, 46, 8, 46]
# Fixed Points:
# H = 840.6724761609639, C = 64.06289645193242, M = 21615.105603346456, N = 31.72523295414388, D = 1.000160813850851, R = 67.27460623200527
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [3250, 155, 35381, 16, 78, 6]
# Fixed Points:
# H = -16.329263840147036, C = -36.53768770833307, M = -12.083262646623677, N = -311.5488688827315, D = 34.75223645382951, R = 376.79663242890194
#
# Eigenvalues of the Jacobian: [25.8656119 +0.j         -2.97720617+0.j          0.38851854+0.j
#  -0.38642647+0.j         -0.8365514 +0.00640688j -0.8365514 -0.00640688j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [1243, 321, 80548, 86, 5, 9]
# Fixed Points:
# H = 840.6724761609644, C = 64.06289645193245, M = 21615.105603346467, N = 31.725232954143873, D = 1.000160813850851, R = 67.27460623200527
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [2408, 344, 25693, 9, 28, 63]
# Fixed Points:
# H = 840.6724761609644, C = 64.06289645193245, M = 21615.105603346463, N = 31.72523295414387, D = 1.000160813850851, R = 67.27460623200528
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [3389, 241, 93202, 3, 62, 35]
# Fixed Points:
# H = 840.6724761609643, C = 64.06289645193246, M = 21615.10560334646, N = 31.725232954143866, D = 1.000160813850851, R = 67.27460623200528
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [1184, 366, 14346, 50, 34, 16]
# Fixed Points:
# H = 30.24302717753213, C = 5.367882458877261, M = 1163.5563400792134, N = 83.62197143350735, D = 0.6687071103123958, R = 15.696462326494013
#
# Eigenvalues of the Jacobian: [-2.48499076e+00+0.j -1.27529135e+00+0.j -8.54264383e-01+0.j
#  -7.49545717e-01+0.j  6.02510445e-06+0.j -9.77710783e-02+0.j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [3835, 357, 60782, 30, 38, 32]
# Fixed Points:
# H = -16.329263840147032, C = -36.53768770833306, M = -12.083262646623675, N = -311.54886888273154, D = 34.75223645382951, R = 376.796632428902
#
# Eigenvalues of the Jacobian: [25.8656119 +0.j         -2.97720617+0.j          0.38851854+0.j
#  -0.38642647+0.j         -0.8365514 +0.00640688j -0.8365514 -0.00640688j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [75, 107, 12738, 24, 33, 43]
# Fixed Points:
# H = 30.24239905310354, C = 5.367842465889433, M = 1163.5404912959043, N = 83.62206218510569, D = 0.6687023385391708, R = 15.696376216828869
#
# Eigenvalues of the Jacobian: [-2.48497824e+00+0.j -1.27529405e+00+0.j -8.54264380e-01+0.j
#  -7.49546537e-01+0.j -4.77507831e-06+0.j -9.77676510e-02+0.j]
#
# The fixed point is stable.
#
#
#
# Initial guess [2340, 5, 31325, 67, 10, 23]
# Fixed Points:
# H = 30.2429835632533, C = 5.367879808633182, M = 1163.5552402945245, N = 83.62197498929676, D = 0.6687067790746734, R = 15.69645904937465
#
# Eigenvalues of the Jacobian: [-2.48498988e+00+0.j -1.27529154e+00+0.j -8.54264383e-01+0.j
#  -7.49545774e-01+0.j  5.25156361e-06+0.j -9.77708313e-02+0.j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [2752, 115, 30123, 23, 0, 77]
# Fixed Points:
# H = 840.6724761609644, C = 64.06289645193246, M = 21615.105603346467, N = 31.72523295414387, D = 1.000160813850851, R = 67.27460623200528
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [402, 372, 35888, 9, 81, 10]
# Fixed Points:
# H = 840.6724761609642, C = 64.06289645193246, M = 21615.105603346456, N = 31.725232954143866, D = 1.0001608138508513, R = 67.27460623200528
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [788, 76, 11371, 54, 14, 32]
# Fixed Points:
# H = 30.241177959394236, C = 5.367764947058245, M = 1163.5096861372901, N = 83.62222757917203, D = 0.6686930681423672, R = 15.696219654277694
#
# Eigenvalues of the Jacobian: [-2.48495384e+00+0.j -1.27529932e+00+0.j -8.54264375e-01+0.j
#  -7.49548136e-01+0.j -2.58551909e-05+0.j -9.77609573e-02+0.j]
#
# The fixed point is stable.
#
#
#
# Initial guess [3730, 11, 32871, 46, 48, 6]
# Fixed Points:
# H = -16.329263840147032, C = -36.53768770833306, M = -12.083262646623675, N = -311.5488688827315, D = 34.75223645382951, R = 376.796632428902
#
# Eigenvalues of the Jacobian: [25.8656119 +0.j         -2.97720617+0.j          0.38851854+0.j
#  -0.38642647+0.j         -0.8365514 +0.00640688j -0.8365514 -0.00640688j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [4031, 153, 96752, 52, 24, 24]
# Fixed Points:
# H = 30.24247810480679, C = 5.367847818555568, M = 1163.5424893304403, N = 83.6220412777169, D = 0.6687029404867297, R = 15.696396383231574
#
# Eigenvalues of the Jacobian: [-2.48497976e+00+0.j -1.27529372e+00+0.j -8.54264381e-01+0.j
#  -7.49546437e-01+0.j -3.49367302e-06+0.j -9.77680537e-02+0.j]
#
# The fixed point is stable.
#
#
#
# Initial guess [174, 329, 33209, 25, 15, 60]
# Fixed Points:
# H = 840.672476160964, C = 64.06289645193245, M = 21615.10560334646, N = 31.725232954143873, D = 1.000160813850851, R = 67.27460623200527
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [3908, 422, 64940, 24, 2, 74]
# Fixed Points:
# H = 840.6724761609648, C = 64.06289645193249, M = 21615.105603346477, N = 31.725232954143824, D = 1.000160813850851, R = 67.27460623200533
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [615, 136, 20173, 74, 25, 1]
# Fixed Points:
# H = 30.242679790256485, C = 5.367859978689493, M = 1163.547570488179, N = 83.62203300422148, D = 0.6687044703208005, R = 15.696403511285375
#
# Eigenvalues of the Jacobian: [-2.48498391e+00+0.j -1.27529284e+00+0.j -8.54264382e-01+0.j
#  -7.49546168e-01+0.j  1.46047796e-07+0.j -9.77692174e-02+0.j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [2038, 125, 2348, 45, 55, 0]
# Fixed Points:
# H = -16.329263840147032, C = -36.53768770833307, M = -12.08326264662367, N = -311.5488688827316, D = 34.75223645382952, R = 376.79663242890206
#
# Eigenvalues of the Jacobian: [25.8656119 +0.j         -2.97720617+0.j          0.38851854+0.j
#  -0.38642647+0.j         -0.8365514 +0.00640688j -0.8365514 -0.00640688j]
#
# The fixed point is unstable.
#
#
#
# Initial guess [3217, 192, 73576, 36, 31, 33]
# Fixed Points:
# H = 840.6724761609643, C = 64.06289645193246, M = 21615.10560334646, N = 31.725232954143866, D = 1.0001608138508513, R = 67.27460623200528
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [3677, 67, 81547, 99, 1, 0]
# Fixed Points:
# H = 840.6724761609643, C = 64.06289645193246, M = 21615.105603346463, N = 31.72523295414387, D = 1.000160813850851, R = 67.27460623200528
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.
#
#
#
# Initial guess [4397, 279, 63721, 4, 32, 64]
# Fixed Points:
# H = 840.672476160964, C = 64.06289645193243, M = 21615.10560334646, N = 31.72523295414388, D = 1.000160813850851, R = 67.27460623200527
#
# Eigenvalues of the Jacobian: [-9.29183732+0.j         -0.09221397+0.56953109j -0.09221397-0.56953109j
#  -1.10515492+0.j         -0.8528667 +0.j         -0.62193918+0.j        ]
#
# The fixed point is stable.

# %% [markdown]
# Run the following cell if you want to store the output of the previous cell in a file.

# %%
        with open('random_guesses.txt', 'a') as file:
            file.write(f'initial_guess: {initial_guess}\n')
            file.write(f'H = {H}, C = {C}, M = {M}, N = {N}, D = {D}, R = {R} \n')
            file.write(f'eigevalues: {eigenvalues}')
#Stability analysis
            if all(np.real(eigenvalues) < 0):
                file.write('STABLE\n\n')
            else:
                file.write('UNSTABLE\n\n')

# %% [markdown]
# ### Latin Hypercube Sampling
# A better way to explore the entire phase space is to use algorithms such as Latin Hypercube Sampling. The following cell samples the variables of interest in a predefined subregion of the phase space. Different possible bounds can be defined. The first selects a wider region of the phase space and is based on the results of the simulations in the reference paper. The others define smaller hypervolumes around the roots identified by running the previous cell.

# %%
def LHS_initial_guess(num_samples):

#Define bounds for variables H, C, M, N; the bound for D is not fixed, it depends on the value of N as D_max = 100 - N
    bounds = np.array([[0, 4500],
                       [0, 450],
                       [0, 100000],
                       [0, 100]])
    min_D = 0.
    min_R = 0.

###############################################################################################################################
#To simulate around a specific fixed point use different bounds:

#fixed_point 1: H = 840.67, C = 64.06, M = 21615.10, N = 31.72, D = 1.00, R = 67.27
    #bounds = np.array([[835, 845],
     #                  [60, 70],
      #                 [21610, 21620],
       #                [30, 34]])
    
    #min_D = 0.
    #min_R = 66.

#fixed_point 2: H = 30.24, C = 5.36, M = 1163.50, N = 83.62, D = 0.66, R = 15.69
    #bounds = np.array([[28, 32],
     #                  [3, 8],
      #                 [1160, 1167],
       #                [80, 87]])
    
    #min_D = 0.
    #min_R = 13.5
    
#fixed_point 3: H = - 16.32, C = - 36.53, M = - 12.08, N = - 311.54, D = 34.75, R = 376.79
    #bounds = np.array([[- 20, - 10],
     #                  [- 40,- 30],
      #                 [- 20,- 5],
       #                [- 320, - 300]])
    
    #min_D = 30.
    #min_R = 370.

#fixed_point 4: H = - 51.45, C = - 1.07, M = - 901.72, N = 101.53, D = 1.47, R = - 3.01
    #bounds = np.array([[- 55, - 48],
     #                  [- 4, 2],
      #                 [- 910, - 890],
       #                [99, 103]])
    
    #min_D = 0.5
    #min_R = -5.

#5 refers to the dimension of the space
#lhs returns a num_samplesX5 matrix of values between 0 and 1, that need to be rescaled according to bounds
    lhs_samples = lhs(5, samples=num_samples)

#Scaling
    scaled_HCMN = bounds[:, 0] + lhs_samples[:,0:4] * (bounds[:, 1] - bounds[:, 0])
    scaled_D = min_D + lhs_samples[:,4] * (100 - scaled_HCMN[:, 3] - min_D - min_R)

#Calculate R as R = 100 - N - D
    R = 100 - scaled_HCMN[:,3] - scaled_D
#and ensure its value does not exceed the range (0, 100)
    R = np.clip(R, 0, 100)
    samples = np.column_stack((scaled_HCMN, scaled_D))

#Append R as the sixth dimension    
    initial_guesses = np.column_stack((samples, R))

    return initial_guesses

# %% [markdown]
# # Visualisation in reduced space
#
# ### Three-dimensional
#
# The following code displays the points extracted using the Latin Hypercube technique in a reduced 3D space for H, C and M, with different colours based on the root the solver would find if the point in question were chosen as the initial guess. Note: this is not a study of the basin of attraction. In fact, the four roots previously found are not actual roots, except for one; they are therefore not true fixed points. Substituting the values into the algebraic system, three of the supposed roots do not truly nullify the equations but only return relatively small values (typically of the order of $10^{-1}$ or $10^{-2}$).

# %%
num_samples = 500

initial_guesses = LHS_initial_guess(num_samples)

#Lists to store the initial guesses and fixed points
initial_H_vals = []
initial_C_vals = []
initial_M_vals = []
initial_N_vals = []
initial_D_vals = []
initial_R_vals = []

fixed_points_H = []
fixed_points_C = []
fixed_points_M = []
fixed_points_N = []
fixed_points_D = []
fixed_points_R = []

for i in range(num_samples):
    initial_guess = initial_guesses[i]

#Storing the initial guesses
    initial_H_vals.append(initial_guess[0])
    initial_C_vals.append(initial_guess[1])
    initial_M_vals.append(initial_guess[2])
    initial_N_vals.append(initial_guess[3])
    initial_D_vals.append(initial_guess[4])
    initial_R_vals.append(initial_guess[5])
    
#Solve the system using the root function with Jacobian
    solution = root(equations, initial_guess, args=(par, H_i, C_i, M_i), jac=jacobian, method='lm')
    if not solution.success:
        print(f'Solution did not converge: {solution.message}')
    else:
        H, C, M, N, D, R = solution.x

        fixed_points_H.append(H)
        fixed_points_C.append(C)
        fixed_points_M.append(M)
        fixed_points_N.append(N)
        fixed_points_D.append(D)
        fixed_points_R.append(R)      

#Convert lists into NumPy arrays for easier processing
initial_H_vals = np.array(initial_H_vals)
initial_C_vals = np.array(initial_C_vals)
initial_M_vals = np.array(initial_M_vals)
initial_N_vals = np.array(initial_N_vals)
initial_D_vals = np.array(initial_D_vals)
initial_R_vals = np.array(initial_R_vals)

fixed_points_H = np.array(fixed_points_H)

#This values were obtaind from previous simulations
fixed_point_H_1 = 840
fixed_point_H_2 = 30
fixed_point_H_3 = -16
fixed_point_H_4 = -51

condition_1 = np.abs(fixed_points_H - fixed_point_H_1) < 1
condition_2 = np.abs(fixed_points_H - fixed_point_H_2) < 1
condition_3 = np.abs(fixed_points_H - fixed_point_H_3) < 1
condition_4 = np.abs(fixed_points_H - fixed_point_H_4) < 1

#Create a 3D scatter plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

#Plot the points based on conditions with different colours
ax.scatter(initial_H_vals[condition_1], initial_C_vals[condition_1], initial_M_vals[condition_1], c='r', marker='o', label='Near fixed point 1')
ax.scatter(initial_H_vals[condition_2], initial_C_vals[condition_2], initial_M_vals[condition_2], c='b', marker='o', label='Near fixed point 2')
ax.scatter(initial_H_vals[condition_3], initial_C_vals[condition_3], initial_M_vals[condition_3], c='y', marker='o', label='Near fixed point 3')
ax.scatter(initial_H_vals[condition_4], initial_C_vals[condition_4], initial_M_vals[condition_4], c='g', marker='o', label='Near fixed point 4')

ax.set_xlabel('H')
ax.set_ylabel('C')
ax.set_zlabel('M')

ax.set_title(f'Convergence for {num_samples} initial guesses \n in the reduced space for H, C and M')
ax.tick_params(axis='z', pad=10, labelrotation=30)

#Zoom in on the region where the points are
ax.set_xlim([min(initial_H_vals) - 1, max(initial_H_vals) + 1])
ax.set_ylim([min(initial_C_vals) - 1, max(initial_C_vals) + 1])
ax.set_zlim([min(initial_M_vals) - 1, max(initial_M_vals) + 1])

ax.legend()

#Adjust the layout manually to ensure labels aren't cut off
fig.subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.1)

#Adjust the aspect ratio of the 3D box to make more room for labels
ax.set_box_aspect([1, 0.9, 0.8])

#plt.savefig('phase_space_HCM.png')

plt.show()
# Out:
# Please insert the number of simulations you want to compute with random initial guesses: 500

# %% [markdown]
# Second plot in the reduced 3D space for N, D and R.

# %%
#Create a 3D scatter plot for the other 3 variables
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(initial_N_vals[condition_1], initial_D_vals[condition_1], initial_R_vals[condition_1], c='r', marker='o', label='Near fixed point 1')
ax.scatter(initial_N_vals[condition_2], initial_D_vals[condition_2], initial_R_vals[condition_2], c='b', marker='o', label='Near fixed point 2')
ax.scatter(initial_N_vals[condition_3], initial_D_vals[condition_3], initial_R_vals[condition_3], c='y', marker='o', label='Near fixed point 3')
ax.scatter(initial_N_vals[condition_4], initial_D_vals[condition_4], initial_R_vals[condition_4], c='g', marker='o', label='Near fixed point 4')

ax.set_xlabel('N')
ax.set_ylabel('D')
ax.set_zlabel('R', labelpad=0.5)

ax.set_title(f'Convergence for {num_samples} initial guesses \n in the reduced space for N, D and R')
ax.tick_params(axis='z', pad=5, labelrotation=30)
ax.legend()

ax.set_xlim([min(initial_N_vals) - 1, max(initial_N_vals) + 1])
ax.set_ylim([0, max(initial_D_vals) + 1])
ax.set_zlim([min(initial_R_vals) - 1, max(initial_R_vals) + 1])

fig.subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.1)
ax.set_box_aspect([1, 0.9, 0.8])

#plt.savefig('phase_space_NDR')

plt.show()

# %% [markdown]
# ### Two-dimensional
#
# Alternatively, a two-dimensional visualisation can be displayed.

# %%
fig, ax = plt.subplots()

#Depending on which variable one is interested in plotting, the initial_*_vals must be modified.
ax.scatter(initial_H_vals[condition_1], initial_C_vals[condition_1], c='r', marker='o', label='Near fixed point 1')
ax.scatter(initial_H_vals[condition_2], initial_C_vals[condition_2], c='b', marker='o', label='Near fixed point 2')
ax.scatter(initial_H_vals[condition_3], initial_C_vals[condition_3], c='y', marker='o', label='Near fixed point 3')
ax.scatter(initial_H_vals[condition_4], initial_C_vals[condition_4], c='g', marker='o', label='Near fixed point 4')

# Set axis labels and title
ax.set_xlabel('H')
ax.set_ylabel('C')
ax.set_title('2D Scatter Plot of H vs C')

# Add a legend
ax.legend()

# Show the plot
plt.show()

# %% [markdown]
# ### 2D sampling with LHS
#
# The following function allows for the sampling of only two variables around a specified point in the phase space. As in the definition of LHS_initial_guess, different bounds can be chosen based on which region of the phase space one wants to systematically explore.

# %%
def LHS_2D_sampling(num_samples, var1, var2, fixed_values):

    all_vars = {'H', 'C', 'M', 'N', 'D', 'R'}
    values_list = list(fixed_values.values())

#Order the variables so that var1 always comes first than var2 in H, C, M, N, D, R
    var_map = {
        'H': 0,
        'C': 1,
        'M': 2,
        'N': 3,
        'D': 4,
        'R': 5
    }

    if var_map[var1] > var_map[var2]:
        var1, var2 = var2, var1
    
#Define bounds for each variable around a specific fixed point

#fixed_point 1: H = 840.67, C = 64.06, M = 21615.10, N = 31.72, D = 1.00, R = 67.27
    bounds = {
        'H': [830, 850],
        'C': [62, 66],
        'M': [21610, 21630],
        'N': [30, 33],
        'D': [0, 2],
        'R': [65, 70]
    }

#fixed_point 2: H = 30.24, C = 5.36, M = 1163.50, N = 83.62, D = 0.66, R = 15.69
#    bounds = {
 #       'H': [25, 35],
  #      'C': [2, 8],
   #     'M': [1150, 1170],
    #    'N': [80, 86],
     #   'D': [0, 2],
      #  'R': [13, 18]
    #}

#fixed_point 3: H = - 16.32, C = - 36.53, M = - 12.08, N = - 311.54, D = 34.75, R = 376.79
#    bounds = {
 #       'H': [- 20, - 10],
  #      'C': [- 40, - 30],
   #     'M': [- 20, - 5],
    #    'N': [- 320, - 300],
     #   'D': [30, 40],
      #  'R': [360, 385]
    #}

#fixed_point 4: H = - 51.45, C = - 1.07, M = - 901.72, N = 101.53, D = 1.47, R = - 3.01
#    bounds = {
 #       'H': [- 55, - 48],
  #      'C': [- 3, 1],
   #     'M': [- 910, - 890],
    #    'N': [97, 104],
     #   'D': [0, 3],
      #  'R': [- 6, 0]
    #}

#Check if var1 and var2 are valid variable names and are different from each other
    if var1 not in bounds or var2 not in bounds:
        raise ValueError(f"Invalid variable names: {var1}, {var2}. Valid names are {list(bounds.keys())}.")
    assert var1 != var2, 'You cannot choose the same variable two times.'

#Perform the check that all 6 variables (H, C, M, N, D, R) are covered
    fixed_keys = set(fixed_values.keys())
    used_vars = fixed_keys.union({var1, var2})
    
    if used_vars != all_vars:
        raise ValueError(f'Your selection does not include all the required variables (H, C, M, N, D, R). Missing variables: {all_vars - used_vars}')
    
#Perform LHS sampling in 2D space for var1 and var2
    lhs_samples = lhs(2, samples=num_samples)

#Extract bounds for the two chosen variables
    var1_bounds = bounds[var1]
    var2_bounds = bounds[var2]

    '''Rescaling   
Variables N, D and R must be handled with care because of the constraint N+D+R=100 
when both var1 and var2 are types of fibers we can sample one and the other is then determined
when only var2 is a fiber its value is fixed'''
#(since var1 precedes var2, the condition where var1 is in {N, D, R} and var2 is in {H, C, M} cannot occur.)
    if var1 == 'N' and var2 == 'D':
        var1_bounds[1] = min(100 - fixed_values['R'], bounds[var1][1])
        var1_samples = var1_bounds[0] + lhs_samples[:, 0] * (var1_bounds[1] - var1_bounds[0])
        var2_samples = 100 - fixed_values['R'] - var1_samples
    elif var1 == 'N' and var2 == 'R':
        var1_bounds[1] = min(100 - fixed_values['D'], bounds[var1][1])
        var1_samples = var1_bounds[0] + lhs_samples[:, 0] * (var1_bounds[1] - var1_bounds[0])
        var2_samples = 100 - fixed_values['D'] - var1_samples
    elif var1 == 'D' and var2 == 'R':
        var1_bounds[1] = min(100 - fixed_values['N'], bounds[var1][1])
        var1_samples = var1_bounds[0] + lhs_samples[:, 0] * (var1_bounds[1] - var1_bounds[0])
        var2_samples = 100 - fixed_values['N'] - var1_samples            
    elif var1 not in ['N', 'D', 'R'] and var2 in ['N', 'D', 'R']:
#get the 2 fixed variables representing muscle tissue and extract their labels from the dictionary var_map
        value1 = (var_map[var2] + 1) % 3 + 3
        value2 = (var_map[var2] + 2) % 3 + 3
        key1 = next(key for key, val in var_map.items() if val == value1)
        key2 = next(key for key, val in var_map.items() if val == value2)  

        var1_samples = var1_bounds[0] + lhs_samples[:, 0] * (var1_bounds[1] - var1_bounds[0])
        var2_samples = [100 - fixed_values[key1] - fixed_values[key2]] * num_samples
    else:
        var1_samples = var1_bounds[0] + lhs_samples[:, 0] * (var1_bounds[1] - var1_bounds[0])
        var2_samples = var2_bounds[0] + lhs_samples[:, 1] * (var2_bounds[1] - var2_bounds[0])   

    initial_guesses = np.zeros((num_samples, 6))
#Assign sampled values to var1 and var2 and fixed values to the other variables
    initial_guesses[:, var_map[var1]] = var1_samples
    initial_guesses[:, var_map[var2]] = var2_samples    
    for var, value in fixed_values.items():
        if var not in [var1, var2]:
            initial_guesses[:, var_map[var]] = value
    
#Calculate R as usual and append it to our initial guess as the sixth dimension
    N = initial_guesses[:, var_map['N']]
    D = initial_guesses[:, var_map['D']]
    R = 100 - N - D
    R = np.clip(R, 0, 100)  #ensure R is in range
    initial_guesses[:, var_map['R']] = R

    return initial_guesses

# %% [markdown]
# The following cell performs a partial sampling in the reduced 2D space related to the variables var1 and var2 around one of the hypotetic fixed points found in the previous simulations. Make sure you have selected the central_point variable consistent with the bounds variable in the definition of latin_2D. As before, the extracted points are displayed in the two-dimensional reduced space of var1 and var2, with different colours based on the root they converge to.

# %%
all_vars = ['H', 'C', 'M', 'N', 'D', 'R']
var_map = {
    'H': 0,
    'C': 1,
    'M': 2,
    'N': 3, 
    'D': 4, 
    'R': 5
}

'''Be careful: the central point and the bounds in the sampling function must be consistent.
If you modify one, remember to modify the other as well.'''
central_point = [840.67, 64.06, 21615.10, 31.72, 1.00, 67.27] #real fixed point
#central_point = [30.24, 5.36, 1163.50, 83.62, 0.66, 15.69] #root 2
#central_point = [- 16.32, - 36.53, - 12.08, - 311.54, 34.75, 376.79] #root 3
#central_point = [- 51.45, - 1.07, - 901.72, 101.53, 1.47, - 3.01] #root 4

#Here you can change the number of samples and the variables you want to be sampled
num_samples = 1500
var1, var2 = ['N', 'D']

if var_map[var1] > var_map[var2]:
        var1, var2 = var2, var1
    
remaining_vars = []
for var in all_vars:
    if var != var1 and var != var2:
        remaining_vars.append(var)
        
#Insert the fixed values for the remaining variables
values = []
for var in remaining_vars:
    values.append(central_point[var_map[var]])

#Create a dictionary with the given fixed values associated with the corresponding variable
fixed_values = dict(zip(remaining_vars, values))

initial_guesses = LHS_2D_sampling(num_samples, var1, var2, fixed_values)

#Lists to store the initial guesses and fixed points
initial_H_vals = []
initial_C_vals = []
initial_M_vals = []
initial_N_vals = []
initial_D_vals = []
initial_R_vals = []

fixed_points_H = []
fixed_points_C = []
fixed_points_M = []
fixed_points_N = []
fixed_points_D = []
fixed_points_R = []

for i in range(num_samples):
    initial_guess = initial_guesses[i]

    initial_H_vals.append(initial_guess[0])
    initial_C_vals.append(initial_guess[1])
    initial_M_vals.append(initial_guess[2])
    initial_N_vals.append(initial_guess[3])
    initial_D_vals.append(initial_guess[4])
    initial_R_vals.append(initial_guess[5])
    
#Solve the system using the root function with Jacobian
    solution = root(equations, initial_guess, args=(par, H_i, C_i, M_i), jac=jacobian, method='lm')
    if not solution.success:
        print(f'Solution did not converge: {solution.message}')
    else:
        H, C, M, N, D, R = solution.x

        fixed_points_H.append(H)
        fixed_points_C.append(C)
        fixed_points_M.append(M)
        fixed_points_N.append(N)
        fixed_points_D.append(D)
        fixed_points_R.append(R)

#Create a dictionary to store the initial values for H, C, M, N, D, R
initial_values = {
    'H': np.array(initial_H_vals),
    'C': np.array(initial_C_vals),
    'M': np.array(initial_M_vals),
    'N': np.array(initial_N_vals),
    'D': np.array(initial_D_vals),
    'R': np.array(initial_R_vals)
}
fixed_points_H = np.array(fixed_points_H)

fixed_points = [840, 30, -16, -51]
conditions = [np.abs(fixed_points_H - fp) < 1 for fp in fixed_points]

fig, ax = plt.subplots()

#Plot the points based on conditions with different colours
colours = ['r', 'b', 'y', 'g']
labels = [f'f.p. {i+1}' for i in range(len(fixed_points))]
    
for i, condition in enumerate(conditions):
    ax.scatter(initial_values[var1][condition], initial_values[var2][condition], 
                c=colours[i], marker='o', label=labels[i])

ax.set_title(f'Convergence for {num_samples} initial values of {var1} and {var2} \n \
({remaining_vars[0]}, {remaining_vars[1]}, {remaining_vars[2]}, {remaining_vars[3]} \
= {values[0]}, {values[1]}, {values[2]}, {values[3]})')
    
ax.set_xlabel(var1)
ax.set_ylabel(var2)
ax.legend()

#plt.savefig(f'{var1}_{var2}_fp.png')
plt.show()
